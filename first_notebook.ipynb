# %% [markdown]
# ## This is my first Jupyter notebook.

# %%
print("My name is Naomi.")
print(4)
# Out:
# My name is Naomi.
# 4

# %% [markdown]
# Importing packages.

# %%
import math
import statistics as stats
import matplotlib.pyplot as plt
import pandas as pd
print(math.log(8, 2))
# Out:
# 3.0

# %% [markdown]
# Opening datasets.
# Jupyter variables -> view variables, ex. dataset dimensions

# %%
carfeatures = pd.read_csv('Lecture_01/data/features.csv')
